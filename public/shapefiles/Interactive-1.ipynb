# %% [markdown]
# Conectado a base (Python 3.13.5)

# %%
pip install simpledbf
pip install pandas 

import simpledbf
import pandas as pd

# Cargar
dbf = simpledbf.Dbf5('GradoMarginacion.dbf')
df = dbf.to_dataframe()

# Homogeneizar
df['COLONIA'] = df['COLONIA'].str.strip().str.upper()
df['CVE_MUN'] = df['CVE_MUN'].str.zfill(5)
df['GM_2020'] = df['GM_2020'].str.strip()
# Out:
#   Cell In[1], line 1
#     pip install simpledbf
#         ^
# SyntaxError: invalid syntax

# %%
pip install simpledbf
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for simpledbf: filename=simpledbf-0.2.6-py3-none-any.whl size=13889 sha256=6dd4180743292ebf3b37f8a488193d2df16a4c812f115f43255f11a646d91efa
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\ee\4b\81\6db04a37ee301f2620476c88f4583c8fd86afb59758d1f0d85
# Successfully built simpledbf
# ...
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: Building 'simpledbf' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'simpledbf'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
pip install pandas as pd
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: pandas in c:\users\admin\anaconda3\lib\site-packages (2.2.3)
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as

# %%
import simpledbf

# %%
import pandas

# %%
dbf = simpledbf.Dbf5('GradoMarginacion.dbf')
df = dbf.to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dbf = simpledbf.Dbf5('GradoMarginacion.dbf')
#       2 df = dbf.to_dataframe()
#
# File c:\Users\ADMIN\anaconda3\Lib\site-packages\simpledbf\simpledbf.py:539, in Dbf5.__init__(self, dbf, codec)
#     537 self._esc = None
#     538 # Reading as binary so bytes will always be returned
# --> 539 self.f = open(dbf, 'rb')
#     541 self.numrec, self.lenheader = struct.unpack('<xxxxLH22x',
#     542         self.f.read(32))
#     543 self.numfields = (self.lenheader - 33) // 32
#
# FileNotFoundError: [Errno 2] No such file or directory: 'GradoMarginacion.dbf'

# %%
dbf = simpledbf.Dbf5(r'C:C:/Users/ADMIN/Documents/Shapes/GradoMarginacion.dbf')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 dbf = simpledbf.Dbf5(r'C:C:/Users/ADMIN/Documents/Shapes/GradoMarginacion.dbf')
#
# File c:\Users\ADMIN\anaconda3\Lib\site-packages\simpledbf\simpledbf.py:539, in Dbf5.__init__(self, dbf, codec)
#     537 self._esc = None
#     538 # Reading as binary so bytes will always be returned
# --> 539 self.f = open(dbf, 'rb')
#     541 self.numrec, self.lenheader = struct.unpack('<xxxxLH22x',
#     542         self.f.read(32))
#     543 self.numfields = (self.lenheader - 33) // 32
#
# OSError: [Errno 22] Invalid argument: 'C:C:/Users/ADMIN/Documents/Shapes/GradoMarginacion.dbf'

# %%
dbf = simpledbf.Dbf5(r'C:C:/Users/ADMIN/Documents/Shapes/GradoMarginacion.dbf')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 dbf = simpledbf.Dbf5(r'C:C:/Users/ADMIN/Documents/Shapes/GradoMarginacion.dbf')
#
# File c:\Users\ADMIN\anaconda3\Lib\site-packages\simpledbf\simpledbf.py:539, in Dbf5.__init__(self, dbf, codec)
#     537 self._esc = None
#     538 # Reading as binary so bytes will always be returned
# --> 539 self.f = open(dbf, 'rb')
#     541 self.numrec, self.lenheader = struct.unpack('<xxxxLH22x',
#     542         self.f.read(32))
#     543 self.numfields = (self.lenheader - 33) // 32
#
# OSError: [Errno 22] Invalid argument: 'C:C:/Users/ADMIN/Documents/Shapes/GradoMarginacion.dbf'

# %%
dbf = simpledbf.Dbf5(r' C:\Users\ADMIN\Documents\Shapes\GradoMarginacion.dbf')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 dbf = simpledbf.Dbf5(r' C:\Users\ADMIN\Documents\Shapes\GradoMarginacion.dbf')
#
# File c:\Users\ADMIN\anaconda3\Lib\site-packages\simpledbf\simpledbf.py:539, in Dbf5.__init__(self, dbf, codec)
#     537 self._esc = None
#     538 # Reading as binary so bytes will always be returned
# --> 539 self.f = open(dbf, 'rb')
#     541 self.numrec, self.lenheader = struct.unpack('<xxxxLH22x',
#     542         self.f.read(32))
#     543 self.numfields = (self.lenheader - 33) // 32
#
# OSError: [Errno 22] Invalid argument: ' C:\\Users\\ADMIN\\Documents\\Shapes\\GradoMarginacion.dbf'

# %%
import os

archivo = 'GradoMarginacion.dbf'

if os.path.exists(archivo):
    print("¡Archivo encontrado!")
else:
    print(f"Error: El archivo '{archivo}' no existe en esta carpeta: {os.getcwd()}")
# Out:
# Error: El archivo 'GradoMarginacion.dbf' no existe en esta carpeta: c:\Users\ADMIN\Documents\shp-map-viewer
